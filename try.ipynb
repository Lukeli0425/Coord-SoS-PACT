# %%
import numpy as np
from matplotlib import pyplot as plt
import torch
from torch.fft import fft2, ifft2, fftshift, ifftshift

from utils.utils_torch import get_fourier_coord
from utils.reconstruction import gaussian_kernel

# %%
x = torch.tensor(gaussian_kernel(5, 160))
X = fft2(ifftshift(x))
k, theta = get_fourier_coord(160, 6.4e-4, 'cpu')
k = ifftshift(k)

# %%
plt.subplot(1,3,1)
plt.imshow(x)

plt.subplot(1,3,2)
plt.imshow(X.abs())

plt.subplot(1,3,3)
plt.imshow(k)
